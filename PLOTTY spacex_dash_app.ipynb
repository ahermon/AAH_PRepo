# %% [markdown]
# # Importing Data

# %%
# Import required libraries
import pandas as pd
import dash
# import dash_html_components as html
# import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px

# %%
from dash import dcc 
# import dash_core_components as dcc
from dash import html

# %%
# skip

# data.head(-1)
# print(data) 

FN = "C:\\temp\\APIspacexdata.csv"
data.to_csv(FN)

# %%
# Read the airline data into pandas 

FN = "C:\\temp\\spacex_launch_dash.csv"
# data.to_csv(FN)

# spacex_df = pd.read_csv("spacex_launch_dash.csv")

spacex_df = pd.read_csv(FN)

max_payload = spacex_df['Payload Mass (kg)'].max()

min_payload = spacex_df['Payload Mass (kg)'].min()

# %%
spacex_df.columns
# Out:
# Index(['Unnamed: 0', 'Flight Number', 'Launch Site', 'class',
#        'Payload Mass (kg)', 'Booster Version', 'Booster Version Category'],
#       dtype='object')

# %% [markdown]
# # marker_status - status_cnt

# %%
# Function to assign color to launch outcome
def assign_marker_status(launch_outcome):
    if launch_outcome == 1:
        return 'Successful'
    else:
        return 'Failed'
    
spacex_df['marker_status'] = spacex_df['class'].apply(assign_marker_status)
spacex_df.tail(10)
# Out:
#     Unnamed: 0  Flight Number   Launch Site  class  Payload Mass (kg)  \
# 46          46             43    KSC LC-39A      1            5200.00
# 47          47             44    KSC LC-39A      1            3500.00
# 48          48             54    KSC LC-39A      1            3600.00
# 49          49             45  CCAFS SLC-40      1            2205.00
# 50          50             47  CCAFS SLC-40      1            3696.65
# 51          51             48  CCAFS SLC-40      0            4230.00
# 52          52             50  CCAFS SLC-40      0            6092.00
# 53          53             52  CCAFS SLC-40      0            2647.00
# 54          54             53  CCAFS SLC-40      1             362.00
# 55          55             56  CCAFS SLC-40      0            5384.00
#
#    Booster Version Booster Version Category marker_status
# 46  F9 FT  B1031.2                       FT    Successful
# 47   F9 B4 B1042.1                       B4    Successful
# ...

# %%
# Function to assign color to launch outcome
def assign_status_cnt(launch_outcome):
    if launch_outcome == 1:
        return 1
    else:
        return 1
    
spacex_df['status_cnt'] = spacex_df['class'].apply(assign_status_cnt)
spacex_df.tail(10)
# Out:
#     Unnamed: 0  Flight Number   Launch Site  class  Payload Mass (kg)  \
# 46          46             43    KSC LC-39A      1            5200.00
# 47          47             44    KSC LC-39A      1            3500.00
# 48          48             54    KSC LC-39A      1            3600.00
# 49          49             45  CCAFS SLC-40      1            2205.00
# 50          50             47  CCAFS SLC-40      1            3696.65
# 51          51             48  CCAFS SLC-40      0            4230.00
# 52          52             50  CCAFS SLC-40      0            6092.00
# 53          53             52  CCAFS SLC-40      0            2647.00
# 54          54             53  CCAFS SLC-40      1             362.00
# 55          55             56  CCAFS SLC-40      0            5384.00
#
#    Booster Version Booster Version Category marker_status  status_cnt
# 46  F9 FT  B1031.2                       FT    Successful           1
# ...

# %%
  # SKIP



options=[x
                       {'label': i, 'value': i} for i in spacex_df.index

                                    print('label:' + i, 'value : ' + i )
                            ],


spacex_df['Launch Site'][i]


                  value='Selec

for i in spacex_df['Launch Site'][i]:

    print(i,'Outcome',lout['Outcome'][i])

# %%
spacex_df['Launch Site'].unique()
# Out:
# array(['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40'],
#       dtype=object)

# %%
# SKIP

sitesdf = spacex_df['Launch Site'].unique()

sitesdf


for i in sitesdf.item:

    print('label:' + sitesdf['Launch Site'][i]
+ '   value : ' + sitesdf['Launch Site'][i])

# %%
# SKIP


for i in spacex_df['Launch Site'].unique.IndexError:

    print('label:' + spacex_df['Launch Site'][i]
+ '   value : ' + spacex_df['Launch Site'][i])

# %%
# lslist
lslist2=spacex_df['Launch Site'].unique()

lslist2

# spacex_df['Launch Site'].unique()
# Out:
# array(['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40'],
#       dtype=object)

# %%
lslist2[2]
# Out:
# 'KSC LC-39A'

# %%
lslist = []

lslist2=spacex_df['Launch Site'].unique()

# lslist2

# df['Stream'][ind]
# landing_class = 0 if bad_outcome
# landing_class = 1 otherwise

for i in lslist2:
    lslist.append(i)

    # print(i,'landing Site',lslist2)

    # loutstr = lout['Outcome'][i]
    # if loutstr in bad_outcomes:
    
lslist.append('ALL')
    # else:
        # lcl.append(1)

lslist
# Out:
# ['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40', 'ALL']

# %%
lslist
# Out:
# ['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40', 'ALL']

# %%
    # 'Launch Site', 'class',

        # recession_data = data[data['Recession'] == 1]


SS = 'CCAFS SLC-40'

ssdf1 = spacex_df[spacex_df['Launch Site'] == SS]
ssdf = ssdf1[ssdf1['class'] ==1]



# ssdf = spacex_df[spacex_df[(['Launch Site'] == SS, ['class'] == 1)]]


ssdf

# %%
# SKIP



spacex_df[spacex_df]

# %%
# Create a dash application
app = dash.Dash(__name__)

# %%
# SKIP





{'label': 'All Sites', 'value': 'ALL'},
                              {'label': 'site1', 'value': 'site1'},
                              {'label': 'site1', 'value': 'site1'},
                              {'label': 'site1', 'value': 'site1'},
                            {'label': 'ALL', 'value': 'ALL'},

# %% [markdown]
# # # TASK 1: Add a dropdown list to enable Launch Site selection

# %%
tabs_styles = {
    'height': '44px'
}
tab_style = {
    'borderBottom': '1px solid #d6d6d6',
    'padding': '6px',
    'fontWeight': 'bold'
}

tab_selected_style = {
    'borderTop': '1px solid #d6d6d6',
    'borderBottom': '1px solid #d6d6d6',
    'backgroundColor': '#119DFF',
    'color': 'yellow',
    'fontWeight': 'bold',
    'padding': '6px'
}

report_heading_style = {

    'textAlign': 'center',
    'color': '#CFD22F',
    'font-size': '20'     
}

# %%
gspacex_df = spacex_df[spacex_df['class'] == 1]
gspacex_df

# %% [markdown]
# ## ssdf = spacex_df[spacex_df['Launch Site'] == dropdown_value]

# %%
ssdf = spacex_df[spacex_df['Launch Site'] ==  'CCAFS SLC-40']

CNT = ssdf.count()

# CNT

ssdf

        # SS = 'CCAFS SLC-40'
# Out:
#     Unnamed: 0  Flight Number   Launch Site  class  Payload Mass (kg)  \
# 49          49             45  CCAFS SLC-40      1            2205.00
# 50          50             47  CCAFS SLC-40      1            3696.65
# 51          51             48  CCAFS SLC-40      0            4230.00
# 52          52             50  CCAFS SLC-40      0            6092.00
# 53          53             52  CCAFS SLC-40      0            2647.00
# 54          54             53  CCAFS SLC-40      1             362.00
# 55          55             56  CCAFS SLC-40      0            5384.00
#
#    Booster Version Booster Version Category marker_status  status_cnt
# 49  F9 FT  B1035.2                       FT    Successful           1
# 50   F9 B4 B1043.1                       B4    Successful           1
# 51  F9 FT  B1032.2                       FT        Failed           1
# 52     F9 B4 B1044                       B4        Failed           1
# ...

# %%
grssdf = ssdf.groupby('Launch Site')['marker_status'].count()

grssdf
# Out:
# Launch Site
# CCAFS SLC-40    7
# Name: marker_status, dtype: int64

# %% [markdown]
# # import plotly.express as px

# %%
import plotly.express as px
# df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
# df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries

fig = px.pie(ssdf
             , values='status_cnt'
             , names='marker_status'
             , title='marker_status of European continent'
            #  ,labels=['marker_status','class']
# 
             )

# labels=['Vehicle_Type','Advertising_Expenditure']),
# 
fig.show()

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %%
ssdf

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries





# fig = px.pie(VTexpenditure, values='Advertising_Expenditure', names='Vehicle_Type', 
            #  title='Share of Each Vehicle Type in Total Expenditure during Recession'
# )
fig.show()

# %% [markdown]
# ##  dcc.RangeSlider(0, 20,

# %%
from dash import Dash, html, dcc, Input, Output, callback

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = Dash(__name__, external_stylesheets=external_stylesheets)
app.layout = html.Div([
    dcc.RangeSlider(0, 20, 1, value=[5, 15], id='my-range-slider'),
    html.Div(id='output-container-range-slider',style=report_heading_style )
])

@callback(
    Output('output-container-range-slider', 'children'),
    Input('my-range-slider', 'value'))
def update_output(value):
        r1 = value[0]
        r2 = value[1]
        return str(r1) + "    "  + str(r2)
# + '  -You have selected "{}"'.format(value)

if __name__ == '__main__':
    app.run(debug=True)

# %%
from dash import Dash, html, dcc, Input, Output, callback

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = Dash(__name__, external_stylesheets=external_stylesheets)
app.layout = html.Div([
    dcc.RangeSlider(
        #   0, 20, 1, value=[5, 15], 
        id='my-range-slider',
              min=0, max=10000, step=1000,
                                    # marks={0: '0',
                                    # 100: '100'},
                value=[min_payload, max_payload]


          ),
    html.Div(id='output-container-range-slider',style=report_heading_style )
])

@callback(
    Output('output-container-range-slider', 'children'),
    Input('my-range-slider', 'value'))
def update_output(value):
        r1 = value[0]
        r2 = value[1]


        c1 = spacex_df.count()



        fspacex_df = spacex_df[spacex_df['Payload Mass (kg)'] >= r1]        

        fspacex_df = fspacex_df[fspacex_df['Payload Mass (kg)'] <= r2]        




        # fspacex_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= r1) & 
        #   spacex_df['Payload Mass (kg)'] <=r2]
        c2 = fspacex_df.count()
        
        
        gspacex_df = fspacex_df[fspacex_df['class'] == 1]        
        c3 = gspacex_df.count()


        return str(c2)      
        # + "    "  + str(c2)   + "    "  + str(c3)


        
        # return str(r1) + "    "  + str(r2)
# + '  -You have selected "{}"'.format(value)

if __name__ == '__main__':
    app.run(debug=True)

# %%
c1

# %%
r1 = 7000
r2 = 10000


c1 = spacex_df.count()



fspacex_df = spacex_df[spacex_df['Payload Mass (kg)'] >= r1]        

fspacex_df = fspacex_df[fspacex_df['Payload Mass (kg)'] <= r2]        


# fspacex_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= r1) & 
          # spacex_df['Payload Mass (kg)'] <=r2]
c2 = fspacex_df.count()
        
        
gspacex_df = fspacex_df[fspacex_df['class'] == 1]        
c3 = gspacex_df.count()

# c2

c3
# Out:
# Unnamed: 0                  3
# Flight Number               3
# Launch Site                 3
# class                       3
# Payload Mass (kg)           3
# Booster Version             3
# Booster Version Category    3
# marker_status               3
# status_cnt                  3
# dtype: int64

# %%
    min=0, max=10000, step=1000,
                                    # marks={0: '0',
                                    # 100: '100'},
                                    value=[min_payload, max_payload]

# %%
    r1 = slider_value[0]
    r2 = slider_value[1]
        # return str(r1) + "    "  + str(r2)



    # recession_data = spacex_df[spacex_df['Recession'] == 1]
    # SS = ''
    SS = 'ALBERTO2'
    XL = 'Launch Site'
    YL = 'class'
    TL = 'ALBERTO'

    # SS = site_dropdown_value

    if dropdown_value =='ALL': 

        fspacex_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= r1) & 
          spacex_df['Payload Mass (kg)'] <=r2] 
        
        # ssdf=fspacex_df
        gspacex_df = fspacex_df[fspacex_df['class'] == 1]


        CNT = gspacex_df.count()

# %% [markdown]
# # app = dash.Dash(__name__)

# %%
# lslis=[]
# lslist=spacex_df['Launch Site'].unique()
import plotly.express as px



lslist = []

lslist2=spacex_df['Launch Site'].unique()

# lslist2
# landing_class = 0 if bad_outcome
# landing_class = 1 otherwise

for i in lslist2:
    lslist.append(i)

    # print(i,'landing Site',lslist2)
    
lslist.append('ALL')

ssdf=spacex_df

df = px.data.tips()



gspacex_df = spacex_df[spacex_df['class'] == 1]





# Create a dash application
app = dash.Dash(__name__)

# Create an app layout

# TASK 1: Add a dropdown list to enable Launch Site selection

# from dash import Dash, dcc, html, Input, Output, callback



app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),




                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                html.Br(),

                                    html.Div(id='output-state'
                                            #  , className='chart-grid'
                                            #  , style={'display': 'flex'}
                                             ,style=tab_selected_style
                                             
                                             ),



 html.Div([
        html.Label("Select Launch Site:"),
        dcc.Dropdown(
            id='site-dropdown', 
                     options=[                         
                    {'label': i, 'value': i} for i in lslist
                    # ,'ALL'
                              ],
                  value='ALL',
                  placeholder='Select a Launch Site.',
                searchable=True,
                  style={'text-align-last': 'center', 'padding': 1,'width': 400, 'color': '#1191ff',
                                'font-size': 20, 'font-weight' : 'bold'}
        ),
            html.Div(id='output-container'
                     , className='chart-grid'
                    #  , style={'display': 'flex'}
                     )

    ]),








                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                

                                
                                # html.Div(dcc.Graph(id='success-pie-chart')),
                                # html.Br(),

                                html.P("Payload range (Kg):"),

                             html.Div([
                                
                                 dcc.RangeSlider(
                                    id='range-slider',

                                    min=0, max=10000, step=1000,
                                    # marks={0: '0',
                                    # 100: '100'},
                                    value=[min_payload, max_payload]

                                    # min=min_payload
                                    # , max=max_payload
                                    # , step=1000,
                                    # marks={0: '0', 2.5: '2.5'},
                                    # ,value=[min_payload,max_payload]
                                    ),
    html.Div(id='slider-output-container',style=report_heading_style )
              ])
                                 
                                
                                 ,
                                 html.Div([ 
                        
                                #  ),
    html.Div(id='success-scatter-output-container')
                            

      ])

    
      ])

# ])

                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)





@app.callback(     
    Output('slider-output-container', 'children'),
     Input(component_id="range-slider", component_property="value") 

    # Input('my-range-slider', 'value')
    )
def update_output(value):
    return 'You have selected "{}"'.format(value)
# ,style=report_heading_style 













# TASK 3: Add a slider to select payload range
#dcc.RangeSlider(id='payload-slider',...)

@app.callback(     
# range-slider
# success-pie-chart
# 'success-scatter-chart
# children
# figure
 Output(component_id='success-scatter-output-container', component_property='children'),
Input(component_id='site-dropdown', component_property='value')
, 
 Input(component_id="range-slider", component_property="value") 
 )

# TASK 4: Add scatter chart to show the correlation between payload and launch success
# html.Div(dcc.Graph(id='success-payload-scatter-chart')),
# ])
# slider_value
def update_graph_container(dropdown_value,slider_value):

    r1 = slider_value[0]
    r2 = slider_value[1]
        # return str(r1) + "    "  + str(r2)



    # recession_data = spacex_df[spacex_df['Recession'] == 1]
    # SS = ''
    SS = 'ALBERTO2'
    XL = 'Launch Site'
    YL = 'class'
    TL = 'ALBERTO'

    # SS = site_dropdown_value

    if dropdown_value =='ALL': 

       
        fspacex_df = spacex_df[spacex_df['Payload Mass (kg)'] >= r1]        

        fspacex_df = fspacex_df[fspacex_df['Payload Mass (kg)'] <= r2]        




        # fspacex_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= r1) & 
        #   spacex_df['Payload Mass (kg)'] <=r2]
        c2 = fspacex_df.count()
        
        
        gspacex_df = fspacex_df[fspacex_df['class'] == 1]        
        c3 = gspacex_df.count()








        
        # ssdf=fspacex_df
        gspacex_df = fspacex_df[fspacex_df['class'] == 1]


        CNT = gspacex_df.count()
        SS = 'ALBERTO'        
        XL = 'Launch Site'
        YL = 'class'
        LL =  'Launch Site'
        TL =  str(r1) +' <=> ' +  str(r2) + 'ALL SUCCESSFUL LAUNCH SITES' + '   '   + str(CNT)
        # Launch Site

    else: 
        # axis_type == 'Linear'

        fspacex_df = spacex_df[spacex_df['Launch Site'] == dropdown_value]


        fspacex_df = fspacex_df[fspacex_df['Payload Mass (kg)'] >= r1]        

        fspacex_df = fspacex_df[fspacex_df['Payload Mass (kg)'] <= r2]   

        gspacex_df = fspacex_df[fspacex_df['class'] == 1]


        CNT = gspacex_df.count()
        # SS = 'CCAFS SLC-40'
        # SS = site_dropdown_value
        SS = 'ALBERTO2'        
        XL =  'marker_status'        
        YL = 'status_cnt'
        LL =  'Launch Site'

        # TL =  str(r1) +' <=> ' +  str(r2) + 'ALL SUCCESSFUL LAUNCH SITES' + '   '   + str(CNT)

        TL = str(r1) +' <=> ' +  str(r2) +  '    ' + dropdown_value + ' Payload Mass (kg) vs Success' + '   '   + str(CNT)
    # return SS

    return html.Div([
            # html.H3('Tab content 1',
    # html.H3('TEXT TITLE',
                    
                    #  style=report_heading_style ,
                    #  {'textAlign': 'center', 'color': '#CFD22F',
                                # 'font-size': 20},                    
                    # ),

dcc.Graph(
                  id='success-scatter-chart',

                                figure = px.scatter(gspacex_df, 
                                 x="Payload Mass (kg)", 
                                 y="class"
                                 ,title=TL

                                ,color=LL, size='Payload Mass (kg)', 
                                hover_data=['Payload Mass (kg)']


                                # ,labels=LL
                                #  trendline="ols"
                                 )
                                 
                
            )
        ])


# TASK 2: Add a pie chart to show the total successful launches count for all sites
# If a specific launch site was selected, show the Success vs. Failed counts for the site
# html.Div(dcc.Graph(id='success-pie-chart')),
# html.Br()



@app.callback(
        Output('output-state', 'children'),
            Input(component_id='site-dropdown',component_property='value'))

            #   Input('submit-button-state', 'n_clicks'),
            # State(component_id='Select-year', component_property='disabled'),
            # State(component_id='crossfilter-yaxis-type', component_property='value'), 

            # State(component_id='dropdown-statistics', component_property='value'), 
            #   State('input-1-state', 'value'),
            #   State('input-2-state', 'value'))

def update_output( input1):
    return f'''
        SELECT 1 is "{input1}"
    '''




# site_dropdown_value

@app.callback(
    Output(component_id='output-container', component_property ='children'),
    # Output('crossfilter-xaxis-type', 'value'),
    Input(component_id='site-dropdown',component_property='value'))
# site_dropdown_value


def update_input_container(dropdown_value):

    # recession_data = spacex_df[spacex_df['Recession'] == 1]
    # SS = ''
    SS = 'ALBERTO2'
    XL = 'Launch Site'
    YL = 'class'
    TL = 'ALBERTO'

    # SS = site_dropdown_value

    if dropdown_value =='ALL': 
        ssdf=spacex_df

        CNT = ssdf.count()
        SS = 'ALBERTO'        
        XL = 'Launch Site'
        YL = 'class'
        LL =  'Launch Site'
        TL = 'ALL SUCCESSFUL LAUNCH SITES' + '   '   + str(CNT)
        # Launch Site

    else: 
        # axis_type == 'Linear'

        ssdf = spacex_df[spacex_df['Launch Site'] == dropdown_value]
        

        CNT = ssdf.count()
        # SS = 'CCAFS SLC-40'
        # SS = site_dropdown_value
        SS = 'ALBERTO2'        
        XL =  'marker_status'        
        YL = 'status_cnt'
        LL =  ''

        TL =  dropdown_value + ' Launches' + '   '   + str(CNT)
    # return SS

    return html.Div([
            # html.H3('Tab content 1',
    html.H3('TEXT TITLE',
                    
                     style=report_heading_style ,
                    #  {'textAlign': 'center', 'color': '#CFD22F',
                                # 'font-size': 20},                    
                    ),

dcc.Graph(
                id='success-pie-chart',

                figure = px.pie(ssdf, 
             values=YL,
               names=XL,
               labels=XL,
                 title=TL
                # figure = px.bar(ssdf,
            #   x='Launch Site', 
            #   y='class',
                # title= 'BAR TEST', 
             
             )
                
            )
        ])





if __name__ == '__main__':
    app.run_server()

# %%
# print(SS)

# %%
# spacex_df['Launch Site'].unique()

# spacex_df.columns
# .count(
spacex_df.count()
# Out:
# Unnamed: 0                  56
# Flight Number               56
# Launch Site                 56
# class                       56
# Payload Mass (kg)           56
# Booster Version             56
# Booster Version Category    56
# dtype: int64

# %% [markdown]
# ##  END

# %%
tspacex_df = spacex_df[spacex_df['class'] == 1]

# tspacex_df.value_counts()

# tspacex_df.value_counts('class')

tspacex_df.value_counts('Launch Site')
# Out:
# Launch Site
# KSC LC-39A      10
# CCAFS LC-40      7
# VAFB SLC-4E      4
# CCAFS SLC-40     3
# Name: count, dtype: int64

# %%
# fspacex_df
fspacex_df.count()
# spacex_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[167], line 2
#       1 # fspacex_df
# ----> 2 fspacex_df.count()
#       3 # spacex_df.count()
#
# NameError: name 'fspacex_df' is not defined

# %%
r2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 r2
#
# NameError: name 'r2' is not defined

# %%
        # ssdf = 
# spacex_df[spacex_df['Launch Site'] == 'VAFB SLC-4E']

# ssdf

CNT = ssdf.count()

CNT
# Out:
# Unnamed: 0                  56
# Flight Number               56
# Launch Site                 56
# class                       56
# Payload Mass (kg)           56
# Booster Version             56
# Booster Version Category    56
# marker_status               56
# status_cnt                  56
# dtype: int64

# %%
ssdf

# %%
islis

# %%
SS=''

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # ex.2 Data Science Tools and Ecosystem

# %% [markdown]
# ## ex.3 In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ex.4
#
# Data science languages play a crucial role in extracting insights from data. Here are some key ones: These languages empower data scientists to work with diverse datasets and build powerful models!
#
#
#
# <ol>
#     <li>	Python	</li>
#     <li>	R	</li>
#     <li>	SQL	</li>
#     <li>	C/C++	</li>
#     <li>	Java	</li>
#     <li>	JavaScript	</li>
#     <li>	Go	</li>
#     <li>	Scala	</li>
#     <li>	Julia	</li>
#     <li>	Swift	</li>
#     <li>	MATLAB	</li>
#     <li>	SAS	</li>
#
# </ol>

# %% [markdown]
# ex.5
#
# Data scientists use various Python libraries and packages like pandas, NumPy, and scikit-learn for data manipulation, analysis, and modeling1.
#
# <ol>
#     <li>	Scrapy	</li>
#     <li>	BeautifulSoup	</li>
#     <li>	Numpy	</li>
#     <li>	Pandas	</li>
#     <li>	SciPy	</li>
#     <li>	Scikit-Learn	</li>
#     <li>	Keras	</li>
#     <li>	PyTorch	</li>
#     <li>	XGBoost	</li>
#     <li>	LightGBM	</li>
#     <li>	TensorFlow	</li>
#     <li>	Matplotlib	</li>
#     <li>	Seaborn	</li>
#     <li>	Plotly	</li>
#     <li>	Pycaret	</li>
#
# </ol>

# %% [markdown]
# ex.6
#
# Data Scientists  must know the extensive and diverse body of knowledge about the tools, skills, and frameworks required.Below are the top, most popular data science tools.
#
#  Their usage helps data scientist perform their monumental tasks efficiently and effectively.
#
#
#
#
# 1.  pandas:
#     1.  A Python library for data manipulation and analysis. It provides intuitive workflows and handles large and complex datasets1.
# 1.  RStudio:
#     1.  An open-source IDE for R, a programming language widely used in data science. RStudio simplifies data analysis and visualization.
# 1.  Apache Spark:
#     1.   An engine for big data processing that supports multiple programming languages, including SQL2.
# 1.  TensorFlow:
#     1.   A machine learning framework developed by Google. It’s widely used for building and training deep learning models.
# 1.  Scrapy:
#     1.   A Python library for web scraping, allowing you to extract data from websites3.
# 1.  the RapidMiner Studio software:
#     1.   is committed to supporting an open-source community of business    analysts and data scientists who can update and improve upon the software.
#     1.  building and training deep learning models.

# %% [markdown]
# <H3>ex.7 Below are a few examples of evaluating arithmetic expressions in Python.</H3>
#
#
# <table>
# <thead>
# <tr>
# <td>
# <p><strong>Operator</strong></p>
# </td>
# <td>
# <p><strong>Description</strong></p>
# </td>
# <td>
# <p><strong>Example</strong></p>
# </td>
# <td>
# <p><strong>Result</strong></p>
# </td>
# </tr>
# <tr>
# <td>
# <p>+</p>
# </td>
# <td>
# <p>Addition</p>
# </td>
# <td>
# <p>2 + 3</p>
# </td>
# <td>
# <p>5</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>-</p>
# </td>
# <td>
# <p>Subtraction</p>
# </td>
# <td>
# <p>5 - 2</p>
# </td>
# <td>
# <p>3</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>*</p>
# </td>
# <td>
# <p>Multiplication</p>
# </td>
# <td>
# <p>4 * 6</p>
# </td>
# <td>
# <p>24</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>/</p>
# </td>
# <td>
# <p>Division</p>
# </td>
# <td>
# <p>11 / 4</p>
# </td>
# <td>
# <p>2.75</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>//</p>
# </td>
# <td>
# <p>Floor division <a href="https://www.learndatasci.com/solutions/python-double-slash-operator-floor-division/#:~:text=In%20Python%2C%20we%20can%20perform,it%20equivalent%20to%20the%20math.">(aka integer division)</a></p>
# </td>
# <td>
# <p>11 // 4</p>
# </td>
# <td>
# <p>2</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>%</p>
# </td>
# <td>
# <p>Modulo (<a href="https://www.geeksforgeeks.org/what-is-a-modulo-operator-in-python/">remainder</a>)</p>
# </td>
# <td>
# <p>11 % 4</p>
# </td>
# <td>
# <p>3</p>
# </td>
# </tr>
# <tr>
# <td>
# <p>**</p>
# </td>
# <td>
# <p>Exponentiation (<a href="https://flexiple.com/python/python-exponents">power</a>)</p>
# </td>
# <td>
# <p>2 ** 3</p>
# </td>
# <td>
# <p>8</p>
# </td>
# </tr>
# </thead>
# </table>

# %%
#ex.8 This a simple arithmetic expression to multiply then add integers

(3*4)+5
# Out:
# 17

# %%
# ex.9 This will convert 200 minutes to hours by diving by 60

m = 300
h = m/60

print( str(m) + "  minute converted to  " + str(h) + " hours")
# Out:
# 300  minute converted to  5.0 hours

# %% [markdown]
# ex.10
#
# This “Final Project:” is demonstrating skills through a Jupyter Notebook project, including Markdown documentation and sharing with peers. Technology and analytical skills that was taught to us throughout this course.
#
# Below are a condensed version of the objrctives of this bourse.
#
# - Module 1 , you will learn about
#     - the different categories of Data Science tools
#     - examples of Open Source and Commercial offerings in each category.
#     -  how the tools overlap in functionality, and
#     - what their pros and cons are.
# - ------------
# - Module 2 - will give an
#     - overview of the commonly used languages that are available in data science
#         - like Python, R, Scala, Java, Julia, and SQL
#     - what they are used for.
# - ------------
# - Module 3 - you will learn about
#     - libraries that contain built-in modules providing different functionalities.
#     - application programming interface (API)
#         - allows communication between 2  pieces of software.
#     - explore open data sets on the Data Asset eXchange (DAX).
#     - how Machine learning (ML) uses algorithms
#         - also known as “models”
#         – to identify patterns in the data.
# - - ------------
# - Module 4 - you will learn about
#     -    Project Jupyter - one  of the most commonly used environments among data scientists.
#     - explore the 3  main applications of Project Jupyter:
#         -  Jupyter Notebook, JupyterLab, and JupyterLite.
#     -  introduced to commercial Jupyter based applications
#         -  such as IBM Watson Studio, and Google Colab.
#     - overview of Jupyter distributions that can be installed on your own system like Anaconda.
# - - ------------
# - Module 5 - you will learn about
#     -  introduction to R and RStudio.
#     - the different R visualization packages
#     -  how to create visual charts using the plot function.
#     - about GitHub, a popular version control platform
#         -  Data Scientists can use for sharing their projects and showcasing their portfolios.
# - - ------------
# - Module 6 - you will
#     - create and share your Jupyter Notebook.
#     - submit your project for peer review
#     -  grade your peers.
# - -- ------------
# - Module 7 - an optional module that gives
#     - an insight into additional IBM tools
#     - like Watson Studio and IBM Cloud Pak
#     - and for data as a service that includes:
#             - IBM Watson Knowledge Catalog, IBM Watson Machine Learning
#             - and more.

# %% [markdown]
# <b>ex.10  Objectives: </b>
#
#
# <ul>	SQL (Structured Query Language)	</lul>
# <ul>	Statistical Analysis System (SAS)	</lul>
# <ul>	Tableau	</lul>
# <ul>	TensorFlow	</lul>

# %% [markdown]
# <p>ex.20 In order to be successful in Data Science, you need to be skilled with using tools that Data Science professionals employ as part of their jobs.
#  This course teaches you about the popular tools in Data Science and how to use them.
#
# You will become familiar with the Data Scientist’s tool kit which includes: Libraries & Packages, Data Sets, Machine Learning Models, Kernels, as well as the various Open source, commercial, Big Data and Cloud-based tools.
#  Work with Jupyter Notebooks, JupyterLab, RStudio IDE, Git, GitHub, and Watson Studio.
#
#  You will understand what each tool is used for, what programming languages they can execute, their features and limitations.
#  This course gives plenty of hands-on experience in order to develop skills for working with these Data Science Tools.
#  With the tools hosted in the cloud on Skills Ne2 rk Labs, you will be able to test each tool and follow instructions to run simple code in Python, R, or Scala.
#
#  Towards the end the course, you will create a final project with a Jupyter Notebook.
#
#
#  You will demonstrate your proficiency preparing a notebook, writing Markdown, and sharing your work with your peers.
#  </p>
#
#
#
# * Module 1 , you will learn about
# * the different categories of Data Science tools
# examples of Open Source and Commercial offerings in each category.
#  how the tools overlap in functionality, and
# what their pros and cons are.
# ------------
# Module 2 - you will learn about
# will give an
# overview of the commonly used languages that are available in data
# science
# like Python, R, Scala, Java, Julia, and SQL
# what they are used for.
#  ------------
# Module 3 - you will learn about
# libraries that contain built-in modules providing
# different functionalities.
# application programming interface (API)
# allows communication between 2  pieces of software.
# explore open data sets on the Data Asset eXchange (DAX).
# how Machine learning (ML) uses algorithms –
#  also known as “models” – to identify patterns in the data.

# %% [markdown]
# ## ex.11 Author
# ## Alberto Hermon
#
#
# Source [Basic Syntax | Markdown Guide](https://www.markdownguide.org/basic-syntax/#links).
#
# Source [12 Top Data Science Programming Languages 2023](
# https://builtin.com/data-science/data-science-programming-languages).
#
# Source [Top Data Science Python Libraries | 15 Python Libraries for Data Science](https://www.analyticsvidhya.com/blog/2021/04/top-15-python-libraries-you-must-know-for-data-science-in-2021/).
#
#
# Source [Top 10 Data Science Tools in 2024 - GUVI Blogs
# ](https://www.guvi.in/blog/data-science-tools/).
